# %% [markdown]
# ### 1. Chat Models

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(
    model = "openai/gpt-oss-20b",
    api_key = os.getenv("GROK_API_KEY"),
    base_url = "https://api.groq.com/openai/v1"
)
prompt = "Explain model component in LangChain in short?"
response = llm.invoke(prompt)
print(response.content)
# Out:
# **Model Component in LangChain (short)**
# - **What it is**: A thin wrapper that lets LangChain talk to any LLM (OpenAI, Anthropic, Gemini, local models, etc.).
# - **Key responsibilities**
#   1. **Prompt handling** – accepts a `PromptTemplate` or plain text, formats it, and passes the final prompt to the LLM.
#   2. **API communication** – sends the prompt to the provider’s endpoint (REST, gRPC, local inference).
#   3. **Response parsing** – returns the raw string or structured output (JSON, CSV, etc.) as defined by the model’s schema.
#   4. **Streaming & retry** – optionally streams tokens and retries on transient errors.
# - **Typical classes**: `BaseLLM`, concrete ones like `OpenAI`, `Anthropic`, `Gemini`, `LLMChain`.
# - **Why it matters**: It abstracts away provider specifics, letting you swap models or use custom ones with minimal code changes.

# %% [markdown]
# ### 2. Embedding Models

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model = "gemini-embedding-001",
    api_key = os.getenv("GEMINI_API_KEY")
)

vector = embeddings.embed_query(
    "What is Generative AI?"
)

print(vector)
# Out:
# [-0.005349091, 0.02172871, 0.031760827, -0.047482654, 0.0055015623, 0.021963757, -0.0023296745, -0.0043597715, -0.022497382, 0.03151454, -0.010548287, -0.008923038, -0.019449497, 0.04050683, 0.14236574, 0.0067799874, 0.004681569, 0.017794907, 0.011712046, -0.015301561, 0.021381225, 0.008607974, 0.02814824, -0.026803073, -0.0027558631, 0.0037915758, 0.010354073, -0.0015537312, 0.03952191, 0.008716364, 0.016290085, 0.0009141774, 0.014831786, 0.01618183, 0.018554516, 0.0031341107, -0.0044493657, -0.015503595, -0.024444554, 0.025721962, -0.024712361, -0.01914522, -0.023457311, -0.015430964, 0.016858434, -0.015662631, 0.00020362686, -0.024059875, 0.014969634, 0.016699709, 0.01544038, 0.01447945, -0.016265688, -0.15938416, -0.0003172303, 0.019204497, -0.00042376827, -0.015240632, -0.013528782, -0.019560857, -0.01733238, 0.001896446, 0.0119837085, -0.024445064, -0.0329941, 0.012002525, 0.039702937, -0.014598955, -0.016693674, -0.00572581, 0.000789833, 0.013690779, 0.01307315, 0.012524801, 0.0018850011, 0.008887665, 0.02585961, 0.0015492232, -0.024125122, 0.0025376691, 0.006241625, 0.011413517, -0.010853892, -0.03191962, -0.018341394, -0.0012998502, -0.016250005, -0.0014298384, 0.010845774, -0.009040911, 0.010859474, -0.011079505, 0.0077943765, -0.0018748011, 0.00036691994, -0.0350355, -0.009150937, 0.0209375, -0.00289431, 0.0087741995, 0.010868742, -0.005798458, 0.021439333, -0.0029305262, -0.007653171, -0.03317293, -0.007704224, 0.0