# %% [markdown]
# ### Hugging Face via API

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id = "openai/gpt-oss-120b",
    task = "text-generation"
)

# %%
model = ChatHuggingFace(
    llm = llm
)

# %%
prompt = "Who is Virat Kohli?"
response = model.invoke(prompt)
print(response.content)
# Out:
# **Virat Kohli** (born 5 November 1988 in Delhi, India) is one of the most celebrated modern cricketers and a global sports icon.
#
# ### Cricketing career
# | Aspect | Highlights |
# |--------|------------|
# | **International debut** | ODI – 18 August 2008 vs Sri Lanka; Test – 20 June 2011 vs West Indies; T20I – 12 June 2010 vs Zimbabwe |
# | **Primary role** | Right‑hand bat; occasional right‑arm medium‑pace bowler |
# | **Batting style** | Aggressive, technically sound, strong on the leg side and in chase situations |
# | **Key records** | • Fastest to 8,000, 9,000, 10,000, 11,000 and 12,000 ODI runs (all in fewer innings than any predecessor)  <br>• Over 70 ODI centuries (second only to Sachin Tendulkar)  <br>• Highest run‑getter for India in Tests (over 8,000 runs) <br>• Holds the highest average (≥50) in both Tests and ODIs among modern players with ≥100 innings |
# | **Captaincy** | • Took over as India’s limited‑overs captain in 2013 (ODI/T20I) and Test captain in 2014 <br>• Led India to the 2013 ICC Champions Trophy final, 2014 Test series win in England, 2016‑17 Test series win in Australia, and the 2018 Asia Cup victory <br>• Stepped down as Test captain after the 2021 series loss to England; gave up limited‑overs captaincy in late 2021 |
# | **Domestic / IPL** | • Plays for Royal Challengers Bangalore (RCB) since the league’s inception (2008). He is the franchise’s leading run‑scorer and has served as captain for many seasons. |
# | **Accolades** | • ICC Cricketer of the Year (Sir Garfield Sobers Trophy) – 2017,
